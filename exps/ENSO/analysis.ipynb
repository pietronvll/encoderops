# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import xarray as xr
import torch
import linear_operator_learning as lol
import numpy as np
from loguru import logger
import treescope
from math import sqrt
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
treescope.register_as_default()
from huggingface_hub import hf_hub_download

# %% [markdown]
# ## Transfer learning task
# Models were trained with CESM dataset and tested on ORAS5 dataset.

# %% [markdown]
# ### Ours - Evolution Operator

# %%
@torch.no_grad()
def modes(obs_Y: torch.Tensor,emb_X: torch.Tensor, emb_Y: torch.Tensor, reg: float=1e-4):
    cov_X = lol.nn.stats.covariance(emb_X)
    cov_X += torch.eye(cov_X.shape[0], device=cov_X.device) * reg
    cov_Y = lol.nn.stats.covariance(emb_Y)
    cov_XY = lol.nn.stats.covariance(emb_X, emb_Y)
    G = torch.linalg.solve(cov_X, cov_XY)
    logger.info("Computed estimator")
    l, Q = torch.linalg.eig(G) # Q @ torch.diag(l) @ Q^-1 = G
    logger.info("Computed eig decomposition")
    obs_shape = obs_Y.shape[1:]
    logger.info(f"Flattening observable shape {obs_shape}")
    norm = sqrt(emb_Y.shape[0])
    coeffs = torch.tensordot(emb_Y.T/norm, obs_Y.view(obs_Y.shape[0], -1)/norm, dims=1)
    logger.info(f"coeffs shape: {coeffs.shape} | min: {coeffs.min():.2f} | max {coeffs.max():.2f} ")
    Z = torch.linalg.solve(cov_Y.cfloat()@Q, coeffs.cfloat())
    logger.info(f"Computed modes, of shape {Z.shape}")
    Z = Z.view(-1, *obs_shape)
    logger.info(f"Reshaped modes to {Z.shape}")
    return l, Q, cov_X, cov_Y, coeffs

# %%
from src.model import EvolutionOperator
from src.data import SSTDataset
from src.configs import SSTDataArgs

repo_id = "CSML-IIT/encoderops"
file_path = "ENSO/EvOp_CESM.pt"
ckpt_path = hf_hub_download(
            repo_id=repo_id,
            filename=file_path,
            repo_type="model")
model = EvolutionOperator.load_from_checkpoint(ckpt_path)
data_args = torch.load(ckpt_path, map_location="cpu", weights_only=False)['SSTDataModule']['data_args']
trainer_args = torch.load(ckpt_path, map_location="cpu", weights_only=False)['hyper_parameters']['trainer_args']
data_args['augmentations'] = False
data_args.pop('observable')
data_args = SSTDataArgs(**data_args)
# Out:
# /media/gturri/projects/encoderops/.venv/lib/python3.11/site-packages/lightning/pytorch/utilities/migration/utils.py:56: The loaded checkpoint was produced with Lightning v2.5.1.post0, which is newer than your current Lightning version: v2.5.1

# %%
# Skipable if datasets are alerady downloaded
from src.data import SSTDataModule

data_args.data_source = 'CESM'
datamodule = SSTDataModule(trainer_args, data_args, num_workers=4)
datamodule.prepare_data()

data_args.data_source = 'ORAS5'
datamodule = SSTDataModule(trainer_args, data_args, num_workers=4)
datamodule.prepare_data()

# %%
from src.data import SSTDataset

ds_oras5_test = SSTDataset(lagtime=1, history_len=data_args.history_len, split="full", land_mask=data_args.mask, data_source="ORAS5")
ds_oras5_train = SSTDataset(lagtime=1, history_len=data_args.history_len, split="train", land_mask=data_args.mask, data_source="ORAS5")
# Out:
# 2025-09-25 18:12:52.953 | INFO     | src.data:__init__:697 - Dataset loaded with 539 samples.
# 2025-09-25 18:12:53.650 | INFO     | src.data:__init__:697 - Dataset loaded with 455 samples.

# %%
from torch.utils.data import DataLoader
ds_train = ds_oras5_train
ds_test = ds_oras5_test

train_dl = DataLoader(ds_train, batch_size=64, shuffle=False)
test_dl = DataLoader(ds_test, batch_size=64, shuffle=False)

# %%
emb_X = []
emb_Y = []
emb_YP = []
X = []
Y = []
times = []
model.eval()
with torch.no_grad():
    for sample in tqdm(train_dl):
        x = sample['x'].to(model.device)
        y = sample['y'].to(model.device)
        times.append([np.datetime64(el) for el in sample['time'][0]]) 
        emb_X.append(model.encoder(x))
        emb_Y.append(model.encoder(y))
        emb_YP.append(model.linear(model.encoder(y)))
        Y.append(y[:,0])
emb_X = torch.cat(emb_X)
emb_Y = torch.cat(emb_Y)
emb_YP = torch.cat(emb_YP)
Y = torch.cat(Y)

embeddings_train = {
    "Y": Y.cpu(),
    "emb_X": emb_X.cpu(),
    "emb_Y": emb_Y.cpu(),
    "emb_YP": emb_YP.cpu(),
    "times": np.concatenate(times)
}

emb_X = []
emb_Y = []
X = []
Y = []
times = []
model.eval()
with torch.no_grad():
    for sample in tqdm(test_dl):
        x = sample['x'].to(model.device)
        y = sample['y'].to(model.device)
        times.append([np.datetime64(el) for el in sample['time'][0]]) 
        emb_X.append(model.encoder(x))
        emb_Y.append(model.encoder(y))
        Y.append(y[:,0])
emb_X = torch.cat(emb_X)
emb_Y = torch.cat(emb_Y)
Y = torch.cat(Y)

embeddings_full = {
    "Y": Y.cpu(),
    "emb_X": emb_X.cpu(),
    "emb_Y": emb_Y.cpu(),
    "times": np.concatenate(times)
}
# Out:
# ...
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
observable_train = embeddings_train["Y"]
observable_full = embeddings_full["Y"]
reg = 1e-5
l, Q, cov_X, cov_Y, coeffs = modes(observable_train, embeddings_train["emb_X"], embeddings_train["emb_Y"], reg=reg)
right_efns = embeddings_full["emb_X"].to(Q.dtype)@Q
reg_cov_Y = (cov_Y + reg*torch.eye(cov_Y.shape[0], dtype=cov_Y.dtype, device=cov_Y.device)).to(Q.dtype)
left_efns = torch.linalg.solve(reg_cov_Y@Q, embeddings_full["emb_X"].to(Q.dtype).T).T
# Out:
# 2025-09-25 18:12:55.243 | INFO     | __main__:modes:8 - Computed estimator
# 2025-09-25 18:12:55.249 | INFO     | __main__:modes:10 - Computed eig decomposition
# 2025-09-25 18:12:55.250 | INFO     | __main__:modes:12 - Flattening observable shape torch.Size([121, 240])
# 2025-09-25 18:12:55.275 | INFO     | __main__:modes:15 - coeffs shape: torch.Size([128, 29040]) | min: -0.31 | max 0.28
# 2025-09-25 18:12:55.300 | INFO     | __main__:modes:17 - Computed modes, of shape torch.Size([128, 29040])
# 2025-09-25 18:12:55.301 | INFO     | __main__:modes:19 - Reshaped modes to torch.Size([128, 121, 240])

# %%
import pandas as pd
from itables import init_notebook_mode
import numpy as np

init_notebook_mode(all_interactive=True)
koopman_values = l.numpy(force=True)

def get_decorrelation(ev, days_lag):
    decorrelation = (1/-np.log(np.abs(ev)))*days_lag / 365.25
    return decorrelation


def get_frequency(ev, days_lag):
    angles = np.angle(ev)
    inv_angles = np.where(np.abs(angles) <= 1e-12, 0, angles**-1)
    frequency = 2 * np.pi * inv_angles*days_lag / 365.25
    return frequency


def get_residuals(l, Q, phi_X, phi_Y):
    cov_X = lol.nn.stats.covariance(phi_X).cfloat()
    cov_XY = lol.nn.stats.covariance(phi_X, phi_Y)
    cov_Y = lol.nn.stats.covariance(phi_Y)

    res2 = []
    for i, eig in enumerate(l):
        q = Q[:, i]
        num = np.vdot(q, (cov_Y - eig * cov_XY.T - eig.conj() * cov_XY + eig.abs()**2 * cov_X) @ q)
        den = np.vdot(q, cov_X @ q)
        res2.append(num / den)

    return np.array(res2)


dict_df = {
    "index": np.arange(len(koopman_values)),
    "real": koopman_values.real,
    "imag": koopman_values.imag,
    "abs": np.abs(koopman_values),
    "decorrelation (yr)": get_decorrelation(koopman_values, 30.5),
    "frequency (yr)": get_frequency(koopman_values, 30.5),
    "residuals": np.abs(get_residuals(l, Q, embeddings_train["emb_X"], embeddings_train["emb_Y"])),
}

results = pd.DataFrame.from_dict(dict_df)
filtered_results = results[results['decorrelation (yr)'] > 1/12]
filtered_results.sort_values(by='decorrelation (yr)', ascending=False, inplace=True)
filtered_results
# Out:
# <script type="module">
#     const { set_or_remove_dark_class } = await import(window._datatables_src_for_itables_2_4_0);
#     set_or_remove_dark_class();
# </script>
# ...

# %%
mode_idx = 4
other_mode_idx = 5
gamma = torch.tensordot(left_efns.T, observable_full.to(left_efns.dtype), dims=1)
plt.imshow(gamma[mode_idx].real, cmap='RdBu_r')
plt.colorbar()
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_7153a7eadfef43b5b21d8e079aa22d04" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream">
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 3))
oni = ds_test.oni.SST.values[1+data_args.history_len:]
times = embeddings_full["times"]
ax.plot(times, oni, color='k', label='ONI')
eigfn = right_efns[:, mode_idx].real
eigfn = 6*eigfn/np.ptp(eigfn)
ax.plot(times, eigfn - eigfn.mean(), color='tab:green', label='Right EFN')
ax.legend(loc='upper right')

ax.axhline(y=0, color='k', lw=0.5)
ax.axvline(x=np.datetime64('2017-01-01'), color='grey', linestyle='--')

ax.set_xmargin(0)
plt.show()

print(pearsonr(oni, eigfn.reshape(-1,1)))
# Out:
# PearsonRResult(statistic=array([0.8150841], dtype=float32), pvalue=array([0.], dtype=float32))

# %%
import scipy
right_efns = (embeddings_full["emb_X"].to(Q.dtype)@Q).numpy(force=True)
QL = reg_cov_Y.numpy(force=True)@Q.numpy(force=True)
cnp = coeffs.numpy(force=True)
cnp[np.isnan(cnp)] = 0.0
Z = scipy.linalg.solve(QL, cnp).reshape(-1, *observable_full.shape[1:])
obs_mode = right_efns[:, mode_idx].reshape(-1, 1, 1) * Z[mode_idx]
if other_mode_idx is not None:
    obs_mode += right_efns[:, other_mode_idx].reshape(-1, 1, 1) * Z[other_mode_idx]
logger.info(f"Max mode imag = {np.abs(obs_mode.imag).max()}")
time_str = [pd.to_datetime(t).strftime('%Y-%m-%d') for t in embeddings_full["times"]]

obs_ds = xr.Dataset(
    {
        "obs_mode": (("time", "lat", "lon"), obs_mode.real),
    },
    coords={
        "time": ("time", time_str),
        "lat": ("lat", ds_oras5_train.ds.coords["latitude"].values[::-1]),
        "lon": ("lon", ds_oras5_train.ds.coords["longitude"].values),
    },
)

obs_ds = obs_ds.isel(lat=slice(None, None, -1))  # Reverse the latitude axis
# Out:
# 2025-09-25 18:12:58.452 | INFO     | __main__:<module>:10 - Max mode imag = 0.0018787384033203125

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
from matplotlib.patches import Rectangle

# --- Data preparation ---

# Extract latitude and longitude from dataset
lat = ds_oras5_test.ds.latitude.values  
lon = ds_oras5_test.ds.longitude.values

# Shift longitude from [0, 360] to [-180, 180] if necessary
lon = np.where(lon > 180, lon - 360, lon)

# Meshgrid for plotting
lon2d, lat2d = np.meshgrid(lon, lat)
data = Z[mode_idx].real

# Center the colormap at 0
absmax = np.abs(data).max()

# --- Plot setup ---

# Set up Cartopy projection centered at 180°E
proj = ccrs.PlateCarree(central_longitude=180)

fig, axs = plt.subplots(ncols=2, figsize=(10, 4), width_ratios=[1, 1])

# --- First panel: Map ---

axs[0].remove()  # Remove the empty subplot
ax_map = plt.subplot(1, 2, 1, projection=proj)
pcm = ax_map.pcolormesh(lon2d, lat2d, data, cmap='RdBu_r', vmin=-absmax, vmax=absmax,
                        transform=ccrs.PlateCarree())

# Add land, coastlines
ax_map.add_feature(cfeature.LAND.with_scale('110m'), facecolor='lightgray', zorder=1)
ax_map.coastlines(resolution='110m', linewidth=0.6)

# Plot ENSO regions
enso_regions = {
    '1+2': {'lon': 270, 'lat': -10, 'width': 10, 'height': 10},
    '3':   {'lon': 210, 'lat': -5,  'width': 60, 'height': 10},
    '3.4': {'lon': 190, 'lat': -5,  'width': 50, 'height': 10},
    '4':   {'lon': 160, 'lat': -5,  'width': 50, 'height': 10},
}
for name, props in enso_regions.items():
    lw = .5
    color = 'tab:red' if name == '3.4' else 'black'
    box = Rectangle((props['lon'], props['lat']), props['width'], props['height'],
                    edgecolor=color, facecolor='none', linewidth=lw,
                    transform=ccrs.PlateCarree(), alpha=0.8)
    ax_map.add_patch(box)
    if name == '1+2':
        ax_map.text(props['lon'] + 2, props['lat'] + props['height'] + 1, name,
                    transform=ccrs.PlateCarree(), fontsize=8, color=color)
    else:
        ax_map.text(props['lon'] + 2, props['lat'] + props['height'] + 1, name,
                    transform=ccrs.PlateCarree(), fontsize=8, color=color)


ax_map.set_xticks([-120, -60, 0, 60, 120, 180], crs=ccrs.PlateCarree())
ax_map.set_xticklabels(['120°W', '60°W', '0°', '60°E', '120°E', '180°'])
ax_map.set_yticks([-90, -60, -30, 0, 30, 60, 90], crs=ccrs.PlateCarree())
ax_map.set_yticklabels(['90°S', '60°S', '30°S', '0°', '30°N', '60°N', '90°N'])
ax_map.set_global()

# --- Second panel: Time series ---

ax = axs[1]
times = embeddings_full["times"]
oni = ds_test.oni.SST.values[1+data_args.history_len:]
ax.plot(times, oni, color='gray', alpha=1, label='ONI')

eigfn = right_efns[:, mode_idx].real
eigfn = eigfn - np.mean(eigfn)
eigfn = eigfn / np.max(np.abs(eigfn)) * np.abs(oni).max()
ax.plot(times, eigfn, color='tab:red', lw=1, label='$\\Psi_{\\mathrm{ENSO}}$')

ax.set_xlabel('Time', labelpad=2)
ax.set_xticklabels([str(year) for year in np.arange(1975, 2025, 5)])
ax.set_ylabel(r'$\degree C$', color='k', labelpad=-2)
ax.set_yticks([-2, 0, 2], labels=['-2', '0', '2'])
ax.axhline(y=0, color='k', lw=0.5)
ax.axvline(x=np.datetime64('2017-01-01'), color='k', linestyle='--', lw=0.5)
ax.set_xmargin(.00)
ax.legend(loc='upper right', framealpha=0, facecolor='white', ncol=2, bbox_to_anchor=(1, 1.2))

plt.tight_layout()
plt.show()

# Save the figure as png
fig.savefig('figures/TL_sst_modes_enso.png', bbox_inches='tight', dpi=300, transparent=True)
# Out:
# /tmp/ipykernel_75809/1400370942.py:82: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([str(year) for year in np.arange(1975, 2025, 5)])

# %% [markdown]
# ### VAMPNets

# %%
#[TODO]

# %% [markdown]
# ### DPNets

# %%
#[TODO]

# %% [markdown]
# ## No transfer learning
# Models trained and tested on ORAS5 dataset.

# %% [markdown]
# ### Ours - Evolution Operator

# %%
@torch.no_grad()
def modes(model: EvolutionOperator, obs_Y: torch.Tensor, emb_Y: torch.Tensor, reg: float=1e-4):
    cov_X = dict(model.named_buffers())['covariances.cov_X'].cpu()
    cov_X += torch.eye(cov_X.shape[0], device=cov_X.device) * reg
    cov_Y = dict(model.named_buffers())['covariances.cov_Y'].cpu()
    cov_XY = dict(model.named_buffers())['covariances.cov_XY'].cpu()
    G = torch.linalg.solve(cov_X, cov_XY)
    print("Computed estimator")
    l, Q = torch.linalg.eig(G) # Q @ torch.diag(l) @ Q^-1 = G
    print("Computed eig decomposition")
    obs_shape = obs_Y.shape[1:]
    print(f"Flattening observable shape {obs_shape}")
    norm = np.sqrt(emb_Y.shape[0])
    coeffs = torch.tensordot(emb_Y.T/norm, obs_Y.view(obs_Y.shape[0], -1)/norm, dims=1)
    print(f"coeffs shape: {coeffs.shape} | min: {coeffs.min():.2f} | max {coeffs.max():.2f} ")
    Z = torch.linalg.solve(cov_Y.cfloat()@Q, coeffs.cfloat())
    print(f"Computed modes, of shape {Z.shape}")
    Z = Z.view(-1, *obs_shape)
    print(f"Reshaped modes to {Z.shape}")
    return l, Q, cov_Y, coeffs

# %%
repo_id = "CSML-IIT/encoderops"
file_path = "ENSO/EvOp_ORAS5.pt"
ckpt_path = hf_hub_download(
            repo_id=repo_id,
            filename=file_path,
            repo_type="model")
model = EvolutionOperator.load_from_checkpoint(ckpt_path)
data_args = torch.load(ckpt_path, map_location="cpu", weights_only=False)['SSTDataModule']['data_args']
trainer_args = torch.load(ckpt_path, map_location="cpu", weights_only=False)['hyper_parameters']['trainer_args']
data_args['augmentations'] = False
data_args.pop('observable')
data_args.pop('normalize_observable')
data_args = SSTDataArgs(**data_args)
# Out:
# /media/gturri/projects/encoderops/.venv/lib/python3.11/site-packages/lightning/pytorch/utilities/migration/utils.py:56: The loaded checkpoint was produced with Lightning v2.5.1.post0, which is newer than your current Lightning version: v2.5.1

# %%
ds_oras5_test = SSTDataset(lagtime=1, history_len=data_args.history_len, split="full", land_mask=data_args.mask, data_source="ORAS5")
ds_oras5_train = SSTDataset(lagtime=1, history_len=data_args.history_len, split="train", land_mask=data_args.mask, data_source="ORAS5")
# Out:
# 2025-09-25 18:13:08.075 | INFO     | src.data:__init__:697 - Dataset loaded with 527 samples.
# 2025-09-25 18:13:08.785 | INFO     | src.data:__init__:697 - Dataset loaded with 443 samples.

# %%
ds_train = ds_oras5_train
ds_test = ds_oras5_test

train_dl = DataLoader(ds_train, batch_size=64, shuffle=False)
test_dl = DataLoader(ds_test, batch_size=64, shuffle=False)

# %%
emb_X = []
emb_Y = []
emb_YP = []
X = []
Y = []
times = []
model.eval()
with torch.no_grad():
    for sample in tqdm(train_dl):
        x = sample['x'].to(model.device)
        y = sample['y'].to(model.device)
        times.append([np.datetime64(el) for el in sample['time'][0]]) 
        emb_X.append(model.encoder(x))
        emb_Y.append(model.encoder(y))
        emb_YP.append(model.linear(model.encoder(y)))
        Y.append(y[:,0])
emb_X = torch.cat(emb_X)
emb_Y = torch.cat(emb_Y)
emb_YP = torch.cat(emb_YP)
Y = torch.cat(Y)

embeddings_train = {
    "Y": Y.cpu(),
    "emb_X": emb_X.cpu(),
    "emb_Y": emb_Y.cpu(),
    "emb_YP": emb_YP.cpu(),
    "times": np.concatenate(times)
}

emb_X = []
emb_Y = []
X = []
Y = []
times = []
model.eval()
with torch.no_grad():
    for sample in tqdm(test_dl):
        x = sample['x'].to(model.device)
        y = sample['y'].to(model.device)
        times.append([np.datetime64(el) for el in sample['time'][0]]) 
        emb_X.append(model.encoder(x))
        emb_Y.append(model.encoder(y))
        Y.append(y[:,0])
emb_X = torch.cat(emb_X)
emb_Y = torch.cat(emb_Y)
Y = torch.cat(Y)

embeddings_full = {
    "Y": Y.cpu(),
    "emb_X": emb_X.cpu(),
    "emb_Y": emb_Y.cpu(),
    "times": np.concatenate(times)
}
# Out:
# ...
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
observable_train = embeddings_train["Y"]
observable_full = embeddings_full["Y"]
reg = 1e-4
l, Q, cov_Y, coeffs = modes(model, observable_train, embeddings_train["emb_Y"], reg=reg)
right_efns = embeddings_full["emb_X"].to(Q.dtype)@Q
reg_cov_Y = (cov_Y + reg*torch.eye(cov_Y.shape[0], dtype=cov_Y.dtype, device=cov_Y.device)).to(Q.dtype)
left_efns = torch.linalg.solve(reg_cov_Y@Q, embeddings_full["emb_X"].to(Q.dtype).T).T
# Out:
# Computed estimator
# Computed eig decomposition
# Flattening observable shape torch.Size([121, 240])
# coeffs shape: torch.Size([256, 29040]) | min: -0.13 | max 0.15
# Computed modes, of shape torch.Size([256, 29040])
# Reshaped modes to torch.Size([256, 121, 240])

# %%
import pandas as pd
from itables import init_notebook_mode
import numpy as np

init_notebook_mode(all_interactive=True)
koopman_values = l.numpy(force=True)

def get_decorrelation(ev, days_lag):
    decorrelation = (1/-np.log(np.abs(ev)))*days_lag / 365.25
    return decorrelation


def get_frequency(ev, days_lag):
    angles = np.angle(ev)
    inv_angles = np.where(np.abs(angles) <= 1e-12, 0, angles**-1)
    frequency = 2 * np.pi * inv_angles*days_lag / 365.25
    return frequency


def get_residuals(l, Q, phi_X, phi_Y):
    cov_X = lol.nn.stats.covariance(phi_X).cfloat()
    cov_XY = lol.nn.stats.covariance(phi_X, phi_Y)
    cov_Y = lol.nn.stats.covariance(phi_Y)

    res2 = []
    for i, eig in enumerate(l):
        q = Q[:, i]
        num = np.vdot(q, (cov_Y - eig * cov_XY.T - eig.conj() * cov_XY + eig.abs()**2 * cov_X) @ q)
        den = np.vdot(q, cov_X @ q)
        res2.append(num / den)

    return np.array(res2)


dict_df = {
    "index": np.arange(len(koopman_values)),
    "real": koopman_values.real,
    "imag": koopman_values.imag,
    "abs": np.abs(koopman_values),
    "decorrelation (yr)": get_decorrelation(koopman_values, 30.5),
    "frequency (yr)": get_frequency(koopman_values, 30.5),
    "residuals": np.abs(get_residuals(l, Q, embeddings_train["emb_X"], embeddings_train["emb_Y"])),
}

results = pd.DataFrame.from_dict(dict_df)
filtered_results = results[results['decorrelation (yr)'] > 1/12]
filtered_results.sort_values(by='decorrelation (yr)', ascending=False, inplace=True)
filtered_results
# Out:
# <script type="module">
#     const { set_or_remove_dark_class } = await import(window._datatables_src_for_itables_2_4_0);
#     set_or_remove_dark_class();
# </script>
# ...

# %%
mode_idx = 17
other_mode_idx = 18
gamma = torch.tensordot(left_efns.T, observable_full.to(left_efns.dtype), dims=1)
plt.imshow(gamma[mode_idx].real, cmap='RdBu_r')
plt.colorbar()
# Out:
# <script> (()=>{ if (customElements.get('treescope-container') === undefined) { class TreescopeContainer extends HTMLElement { constructor() { super(); this.attachShadow({mode: "open"}); this.defns = {}; this.state = {}; } } customElements.define("treescope-container", TreescopeContainer); } if (customElements.get('treescope-run-here') === undefined) { class RunHere extends HTMLElement { constructor() { super() } connectedCallback() { const run = child => { const fn = new Function(child.textContent); child.textContent = ""; fn.call(this); this.remove(); }; const child = this.querySelector("script"); if (child) { run(child); } else { new MutationObserver(()=>{ run(this.querySelector("script")); }).observe(this, {childList: true}); } } } customElements.define("treescope-run-here", RunHere); } })(); </script> <treescope-container class="treescope_out_78c31d8ef73145dc87743e64914f3005" style="display:block"></treescope-container> <treescope-run-here><script type="application/octet-stream">
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 3))
oni = ds_test.oni.SST.values[1+data_args.history_len:]
times = embeddings_full["times"]
ax.plot(times, oni, color='k', label='ONI')
eigfn = right_efns[:, mode_idx].real
eigfn = 6*eigfn/np.ptp(eigfn)
ax.plot(times, eigfn - eigfn.mean(), color='tab:green', label='Right EFN')
ax.legend(loc='upper right')

ax.axhline(y=0, color='k', lw=0.5)
ax.axvline(x=np.datetime64('2017-01-01'), color='grey', linestyle='--')

ax.set_xmargin(0)
plt.show()

print(pearsonr(oni, eigfn.reshape(-1,1)))
# Out:
# PearsonRResult(statistic=array([0.718304], dtype=float32), pvalue=array([0.], dtype=float32))

# %%
import scipy
right_efns = (embeddings_full["emb_X"].to(Q.dtype)@Q).numpy(force=True)
QL = reg_cov_Y.numpy(force=True)@Q.numpy(force=True)
cnp = coeffs.numpy(force=True)
cnp[np.isnan(cnp)] = 0.0
Z = scipy.linalg.solve(QL, cnp).reshape(-1, *observable_full.shape[1:])
obs_mode = right_efns[:, mode_idx].reshape(-1, 1, 1) * Z[mode_idx]
if other_mode_idx is not None:
    obs_mode += right_efns[:, other_mode_idx].reshape(-1, 1, 1) * Z[other_mode_idx]
logger.info(f"Max mode imag = {np.abs(obs_mode.imag).max()}")
time_str = [pd.to_datetime(t).strftime('%Y-%m-%d') for t in embeddings_full["times"]]

obs_ds = xr.Dataset(
    {
        "obs_mode": (("time", "lat", "lon"), obs_mode.real),
    },
    coords={
        "time": ("time", time_str),
        "lat": ("lat", ds_oras5_train.ds.coords["latitude"].values[::-1]),
        "lon": ("lon", ds_oras5_train.ds.coords["longitude"].values),
    },
)

obs_ds = obs_ds.isel(lat=slice(None, None, -1))  # Reverse the latitude axis
# Out:
# 2025-09-25 18:13:21.203 | INFO     | __main__:<module>:10 - Max mode imag = 1.0669231414794922e-05

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
from matplotlib.patches import Rectangle

# --- Data preparation ---

# Extract latitude and longitude from dataset
lat = ds_oras5_test.ds.latitude.values  
lon = ds_oras5_test.ds.longitude.values

# Shift longitude from [0, 360] to [-180, 180] if necessary
lon = np.where(lon > 180, lon - 360, lon)

# Meshgrid for plotting
lon2d, lat2d = np.meshgrid(lon, lat)
data = Z[mode_idx].real

# Center the colormap at 0
absmax = np.abs(data).max()

# --- Plot setup ---

# Set up Cartopy projection centered at 180°E
proj = ccrs.PlateCarree(central_longitude=180)

fig, axs = plt.subplots(ncols=2, figsize=(10, 4), width_ratios=[1, 1])

# --- First panel: Map ---

axs[0].remove()  # Remove the empty subplot
ax_map = plt.subplot(1, 2, 1, projection=proj)
pcm = ax_map.pcolormesh(lon2d, lat2d, data, cmap='RdBu_r', vmin=-absmax, vmax=absmax,
                        transform=ccrs.PlateCarree())

# Add land, coastlines
ax_map.add_feature(cfeature.LAND.with_scale('110m'), facecolor='lightgray', zorder=1)
ax_map.coastlines(resolution='110m', linewidth=0.6)

# Plot ENSO regions
enso_regions = {
    '1+2': {'lon': 270, 'lat': -10, 'width': 10, 'height': 10},
    '3':   {'lon': 210, 'lat': -5,  'width': 60, 'height': 10},
    '3.4': {'lon': 190, 'lat': -5,  'width': 50, 'height': 10},
    '4':   {'lon': 160, 'lat': -5,  'width': 50, 'height': 10},
}
for name, props in enso_regions.items():
    lw = .5
    color = 'tab:red' if name == '3.4' else 'black'
    box = Rectangle((props['lon'], props['lat']), props['width'], props['height'],
                    edgecolor=color, facecolor='none', linewidth=lw,
                    transform=ccrs.PlateCarree(), alpha=0.8)
    ax_map.add_patch(box)
    if name == '1+2':
        ax_map.text(props['lon'] + 2, props['lat'] + props['height'] + 1, name,
                    transform=ccrs.PlateCarree(), fontsize=8, color=color)
    else:
        ax_map.text(props['lon'] + 2, props['lat'] + props['height'] + 1, name,
                    transform=ccrs.PlateCarree(), fontsize=8, color=color)


ax_map.set_xticks([-120, -60, 0, 60, 120, 180], crs=ccrs.PlateCarree())
ax_map.set_xticklabels(['120°W', '60°W', '0°', '60°E', '120°E', '180°'])
ax_map.set_yticks([-90, -60, -30, 0, 30, 60, 90], crs=ccrs.PlateCarree())
ax_map.set_yticklabels(['90°S', '60°S', '30°S', '0°', '30°N', '60°N', '90°N'])
ax_map.set_global()

# --- Second panel: Time series ---

ax = axs[1]
times = embeddings_full["times"]
oni = ds_test.oni.SST.values[1+data_args.history_len:]
ax.plot(times, oni, color='gray', alpha=1, label='ONI')

eigfn = right_efns[:, mode_idx].real
eigfn = eigfn - np.mean(eigfn)
eigfn = eigfn / np.max(np.abs(eigfn)) * np.abs(oni).max()
ax.plot(times, eigfn, color='tab:red', lw=1, label='$\\Psi_{\\mathrm{ENSO}}$')

ax.set_xlabel('Time', labelpad=2)
ax.set_xticklabels([str(year) for year in np.arange(1975, 2025, 5)])
ax.set_ylabel(r'$\degree C$', color='k', labelpad=-2)
ax.set_yticks([-2, 0, 2], labels=['-2', '0', '2'])
ax.axhline(y=0, color='k', lw=0.5)
ax.axvline(x=np.datetime64('2017-01-01'), color='k', linestyle='--', lw=0.5)
ax.set_xmargin(.00)
ax.legend(loc='upper right', framealpha=0, facecolor='white', ncol=2, bbox_to_anchor=(1, 1.2))

plt.tight_layout()
plt.show()

# Save the figure as png
fig.savefig('figures/sst_modes_enso.png', bbox_inches='tight', dpi=300, transparent=True)
# Out:
# /tmp/ipykernel_75809/4070363597.py:82: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([str(year) for year in np.arange(1975, 2025, 5)])

# %% [markdown]
# ### VAMPNets

# %%
#[TODO]

# %% [markdown]
# ### DPNets

# %%
#[TODO]
