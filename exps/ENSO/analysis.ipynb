# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # ENSO Analysis
#
# This notebook compares pretrained Evolution Operator, VAMPNets, and DPNets models on the ENSO benchmark.
#
# - Transfer learning: checkpoints trained on `CESM`, analyzed on `ORAS5`
# - No transfer learning: checkpoints trained and analyzed on `ORAS5`
#
# The notebook is intentionally self-contained: all reusable logic lives below as notebook functions.

# %%
import warnings
from dataclasses import asdict
from pathlib import Path

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import linear_operator_learning as lol
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import torch
import xarray as xr
from dotenv import load_dotenv
from IPython.display import display
from itables import init_notebook_mode
from matplotlib.patches import Rectangle
from scipy.stats import pearsonr
from torch.utils.data import DataLoader
from tqdm.auto import tqdm

from src.checkpoints import resolve_checkpoint_path
from src.configs import SSTDataArgs
from src.data import SSTDataModule, SSTDataset
from src.model import EvolutionOperator

load_dotenv(Path('.env'))
init_notebook_mode(all_interactive=True)

# %% [markdown]
# ## Notebook Parameters
#
# Edit only this cell to change the main notebook behavior.
#
# - Set `checkpoint_source = "local"` to use locally trained checkpoints.
# - Use `mode_overrides` to force a specific Koopman mode for one analysis.
# - Set `prepare_datasets = True` if the required datasets are not available yet.

# %%
checkpoint_source = "hf"  # "hf" or "local"
local_checkpoint_root = Path(".")
dataset_root = None  # Optional explicit dataset directory. Otherwise use DATA_PATH from .env.

analysis_source = "ORAS5"
batch_size = 64
num_workers = 0
reg = 1e-4
min_decorrelation_years = 1 / 12
max_auto_candidates = 12
candidate_rows_to_show = 8
min_abs_correlation_warning = 0.20
prepare_datasets = False

save_figures = False
figure_dir = Path("figures/ENSO")
figure_dpi = 200

mode_overrides = {
    "evop_transfer": None,
    "vamp_transfer": None,
    "dp_transfer": None,
    "evop_notransfer": None,
    "vamp_notransfer": None,
    "dp_notransfer": None,
}

# %% [markdown]
# ## Analysis Helpers
#
# The helper functions below keep the rest of the notebook short:
#
# - checkpoint loading
# - dataset construction
# - embedding extraction
# - Koopman mode computation
# - candidate-mode ranking against the ONI signal
# - plotting and final comparison

# %%
_PREPARED_DATA_SOURCES = set()


def checkpoint_path(repo_id: str, filename: str, repo_type: str = "model"):
    if checkpoint_source == "local":
        return resolve_checkpoint_path(
            source="local",
            local_path=local_checkpoint_root / filename,
        )
    return resolve_checkpoint_path(
        source="hf",
        repo_id=repo_id,
        filename=filename,
        repo_type=repo_type,
    )



def build_data_args(checkpoint_state: dict) -> SSTDataArgs:
    data_args = dict(checkpoint_state["SSTDataModule"]["data_args"])
    data_args["augmentations"] = False
    data_args.pop("observable", None)
    data_args.pop("normalize_observable", None)
    if dataset_root is not None:
        data_args["data_path"] = str(dataset_root)
    return SSTDataArgs(**data_args)



def load_enso_checkpoint(
    checkpoint_file: str,
    *,
    strict: bool,
    expected_data_source: str,
):
    repo_id = "CSML-IIT/encoderops"
    ckpt_path = checkpoint_path(repo_id=repo_id, filename=checkpoint_file, repo_type="model")
    checkpoint_state = torch.load(ckpt_path, map_location="cpu", weights_only=False)
    model = EvolutionOperator.load_from_checkpoint(
        ckpt_path,
        map_location="cpu",
        strict=strict,
    )
    data_args = build_data_args(checkpoint_state)
    trainer_args = checkpoint_state["hyper_parameters"]["trainer_args"]

    if data_args.data_source != expected_data_source:
        raise ValueError(
            f"Checkpoint {checkpoint_file} stores data_args.data_source={data_args.data_source!r}, "
            f"expected {expected_data_source!r}."
        )

    return model, data_args, trainer_args, checkpoint_state



def maybe_prepare_sst_data(trainer_args, data_args: SSTDataArgs, sources):
    if not prepare_datasets:
        return

    for source in sources:
        if source in _PREPARED_DATA_SOURCES:
            continue
        dm_data_args = SSTDataArgs(**{**asdict(data_args), "data_source": source})
        datamodule = SSTDataModule(trainer_args, dm_data_args, num_workers=num_workers)
        datamodule.prepare_data()
        _PREPARED_DATA_SOURCES.add(source)



def build_sst_datasets(data_args: SSTDataArgs, source: str):
    train_ds = SSTDataset(
        lagtime=1,
        history_len=data_args.history_len,
        data_path=data_args.data_path,
        split="train",
        land_mask=data_args.mask,
        data_source=source,
    )
    full_ds = SSTDataset(
        lagtime=1,
        history_len=data_args.history_len,
        data_path=data_args.data_path,
        split="full",
        land_mask=data_args.mask,
        data_source=source,
    )
    if len(train_ds) == 0 or len(full_ds) == 0:
        raise ValueError(f"Empty SST dataset for source={source!r}.")
    return train_ds, full_ds



def make_dataloaders(train_ds, full_ds):
    train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=False, num_workers=num_workers)
    full_dl = DataLoader(full_ds, batch_size=batch_size, shuffle=False, num_workers=num_workers)
    return train_dl, full_dl



@torch.no_grad()
def collect_embeddings(model: EvolutionOperator, dataloader: DataLoader, feature_space: str):
    """Collect embeddings, observations, and timestamps for one dataset split."""
    emb_X = []
    emb_Y = []
    emb_YP = []
    Y = []
    times = []

    model.eval()
    device = next(model.parameters()).device
    for sample in tqdm(dataloader):
        x = sample["x"].to(device)
        y = sample["y"].to(device)
        times.append([np.datetime64(el) for el in sample["time"][0]])

        if feature_space == "evop":
            z_x = model.encoder(x)
            z_y = model.encoder(y)
            z_pred = model.linear(z_y)
            emb_YP.append(z_pred.cpu())
        elif feature_space == "baseline":
            z_x = model.forward_nn(x, lagged=False)
            z_y = model.forward_nn(y, lagged=False)
        else:
            raise ValueError(f"Unknown feature_space={feature_space!r}.")

        emb_X.append(z_x.cpu())
        emb_Y.append(z_y.cpu())
        Y.append(y[:, 0].cpu())

    embeddings = {
        "Y": torch.cat(Y),
        "emb_X": torch.cat(emb_X),
        "emb_Y": torch.cat(emb_Y),
        "times": np.concatenate(times),
    }
    if emb_YP:
        embeddings["emb_YP"] = torch.cat(emb_YP)
    return embeddings

# %%
def flatten_1d(values):
    return np.asarray(values).reshape(-1)



def align_series(*series, min_length: int = 1):
    arrays = [flatten_1d(values) for values in series]
    length = min(len(arr) for arr in arrays)
    if length < min_length:
        raise ValueError(f"Need at least {min_length} aligned samples, found {length}.")
    return [arr[:length] for arr in arrays]



def align_time_series(times, *series, min_length: int = 2):
    time_array = flatten_1d(times)
    series_arrays = [flatten_1d(values) for values in series]
    length = min([len(time_array), *[len(arr) for arr in series_arrays]])
    if length < min_length:
        raise ValueError(f"Need at least {min_length} aligned time samples, found {length}.")
    return time_array[:length], *(arr[:length] for arr in series_arrays)



def correlation_coefficient(x, y):
    x_arr, y_arr = align_series(x, y, min_length=2)
    if np.ptp(x_arr) <= 1e-12 or np.ptp(y_arr) <= 1e-12:
        return np.nan
    return float(pearsonr(x_arr, y_arr)[0])



def get_covariances(model, embeddings_train: dict, covariance_source: str):
    if covariance_source == "empirical":
        cov_X = lol.nn.stats.covariance(embeddings_train["emb_X"])
        cov_Y = lol.nn.stats.covariance(embeddings_train["emb_Y"])
        cov_XY = lol.nn.stats.covariance(embeddings_train["emb_X"], embeddings_train["emb_Y"])
    elif covariance_source == "checkpoint":
        buffers = dict(model.named_buffers())
        cov_X = buffers["covariances.cov_X"].detach().cpu().clone()
        cov_Y = buffers["covariances.cov_Y"].detach().cpu().clone()
        cov_XY = buffers["covariances.cov_XY"].detach().cpu().clone()
    else:
        raise ValueError(f"Unknown covariance_source={covariance_source!r}.")

    cov_X = cov_X + reg * torch.eye(cov_X.shape[0], dtype=cov_X.dtype, device=cov_X.device)
    return cov_X, cov_Y, cov_XY



@torch.no_grad()
def solve_mode_decomposition(
    model,
    embeddings_train: dict,
    embeddings_full: dict,
    *,
    covariance_source: str,
):
    observable_train = embeddings_train["Y"]
    observable_full = embeddings_full["Y"]
    cov_X, cov_Y, cov_XY = get_covariances(model, embeddings_train, covariance_source)

    transfer_operator = torch.linalg.solve(cov_X, cov_XY)
    eigvals, Q = torch.linalg.eig(transfer_operator)

    norm = np.sqrt(embeddings_train["emb_Y"].shape[0])
    coeffs = torch.tensordot(
        embeddings_train["emb_Y"].T / norm,
        observable_train.view(observable_train.shape[0], -1) / norm,
        dims=1,
    )

    right_efns = embeddings_full["emb_X"].to(Q.dtype) @ Q
    reg_cov_Y = (cov_Y + reg * torch.eye(cov_Y.shape[0], dtype=cov_Y.dtype, device=cov_Y.device)).to(Q.dtype)
    left_efns = torch.linalg.solve(reg_cov_Y @ Q, embeddings_full["emb_X"].to(Q.dtype).T).T

    QL = reg_cov_Y.numpy(force=True) @ Q.numpy(force=True)
    coeffs_np = coeffs.numpy(force=True)
    coeffs_np[np.isnan(coeffs_np)] = 0.0
    modes = scipy.linalg.solve(QL, coeffs_np).reshape(-1, *observable_full.shape[1:])

    gamma = torch.tensordot(left_efns.T, observable_full.to(left_efns.dtype), dims=1)

    return {
        "observable_train": observable_train,
        "observable_full": observable_full,
        "cov_X": cov_X,
        "cov_Y": cov_Y,
        "cov_XY": cov_XY,
        "eigvals": eigvals,
        "Q": Q,
        "coeffs": coeffs,
        "right_efns": right_efns,
        "left_efns": left_efns,
        "modes": modes,
        "gamma": gamma,
    }



def build_mode_table(eigvals, Q, embeddings_train, right_efns, oni, days_lag: float = 30.5):
    koopman_values = eigvals.numpy(force=True)
    cov_X = lol.nn.stats.covariance(embeddings_train["emb_X"]).cfloat()
    cov_XY = lol.nn.stats.covariance(embeddings_train["emb_X"], embeddings_train["emb_Y"])
    cov_Y = lol.nn.stats.covariance(embeddings_train["emb_Y"])

    residuals = []
    oni_corr = []
    for idx, eig in enumerate(eigvals):
        q = Q[:, idx]
        operator = cov_Y - eig * cov_XY.T - eig.conj() * cov_XY + eig.abs() ** 2 * cov_X
        num = torch.vdot(q, operator.to(q.dtype) @ q)
        den = torch.vdot(q, cov_X.to(q.dtype) @ q)
        residuals.append((num / den).abs().item())

        eigfn = right_efns[:, idx].real.numpy(force=True)
        oni_corr.append(correlation_coefficient(oni, eigfn))

    with np.errstate(divide="ignore", invalid="ignore"):
        decorrelation = (1 / -np.log(np.abs(koopman_values))) * days_lag / 365.25
    angles = np.angle(koopman_values)
    inv_angles = np.zeros_like(angles, dtype=float)
    valid_angles = np.abs(angles) > 1e-12
    inv_angles[valid_angles] = 1.0 / angles[valid_angles]
    frequency = 2 * np.pi * inv_angles * days_lag / 365.25

    results = pd.DataFrame(
        {
            "index": np.arange(len(koopman_values)),
            "real": koopman_values.real,
            "imag": koopman_values.imag,
            "abs": np.abs(koopman_values),
            "decorrelation (yr)": decorrelation,
            "frequency (yr)": frequency,
            "residuals": residuals,
            "oni_corr": oni_corr,
            "abs_oni_corr": np.abs(oni_corr),
        }
    )
    return results



def build_candidate_modes(results: pd.DataFrame):
    candidates = results[
        (results["index"] != 0)
        & (results["decorrelation (yr)"] > min_decorrelation_years)
    ].copy()
    candidates.sort_values(["abs_oni_corr", "decorrelation (yr)"], ascending=[False, False], inplace=True)
    return candidates



def select_mode(results: pd.DataFrame, candidate_modes: pd.DataFrame, mode_idx_override=None):
    if mode_idx_override is None:
        if candidate_modes.empty:
            raise ValueError("No admissible candidate modes were found.")
        selected = candidate_modes.head(max_auto_candidates).iloc[0].copy()
        selection = "automatic"
    else:
        selected_df = results[results["index"] == int(mode_idx_override)]
        if selected_df.empty:
            raise ValueError(f"Mode override {mode_idx_override} is not present in the eigenspectrum.")
        selected = selected_df.iloc[0].copy()
        selection = "manual"

    mode_idx = int(selected["index"])
    oni_corr = float(selected["oni_corr"]) if not np.isnan(selected["oni_corr"]) else np.nan
    sign = 1.0 if np.isnan(oni_corr) or oni_corr >= 0 else -1.0

    if selection == "automatic" and (
        np.isnan(oni_corr) or abs(oni_corr) < min_abs_correlation_warning
    ):
        warnings.warn(
            f"Selected mode {mode_idx} has weak ONI correlation ({oni_corr:.3f})."
        )

    return {
        "index": mode_idx,
        "mode_idx": mode_idx,
        "selection": selection,
        "sign": sign,
        "real": float(selected["real"]),
        "imag": float(selected["imag"]),
        "abs": float(selected["abs"]),
        "decorrelation (yr)": float(selected["decorrelation (yr)"]),
        "frequency (yr)": float(selected["frequency (yr)"]),
        "residuals": float(selected["residuals"]),
        "oni_corr": oni_corr,
        "abs_oni_corr": float(selected["abs_oni_corr"]) if not np.isnan(selected["abs_oni_corr"]) else np.nan,
    }



def build_obs_mode_dataset(times, mode_series, spatial_mode, train_ds):
    time_strings = [pd.to_datetime(t).strftime("%Y-%m-%d") for t in times]
    obs_mode = mode_series.reshape(-1, 1, 1) * spatial_mode
    obs_ds = xr.Dataset(
        {"obs_mode": (("time", "lat", "lon"), obs_mode)},
        coords={
            "time": ("time", time_strings),
            "lat": ("lat", train_ds.ds.coords["latitude"].values[::-1]),
            "lon": ("lon", train_ds.ds.coords["longitude"].values),
        },
    )
    return obs_ds.isel(lat=slice(None, None, -1))



def maybe_save_current_figure(stem: str):
    if not save_figures:
        return
    figure_dir.mkdir(parents=True, exist_ok=True)
    plt.gcf().savefig(figure_dir / f"{stem}.png", dpi=figure_dpi, bbox_inches="tight")



def display_candidate_modes(analysis: dict, n_rows: int = None):
    if n_rows is None:
        n_rows = candidate_rows_to_show

    cols = [
        "index",
        "oni_corr",
        "abs_oni_corr",
        "decorrelation (yr)",
        "frequency (yr)",
        "residuals",
    ]
    display(analysis["candidate_modes"][cols].head(n_rows))
    display(
        pd.DataFrame(
            [
                {
                    "analysis": analysis["analysis_id"],
                    "selection": analysis["selected_mode"]["selection"],
                    "mode_idx": analysis["selected_mode"]["mode_idx"],
                    "oni_corr": analysis["selected_mode"]["oni_corr"],
                    "decorrelation (yr)": analysis["selected_mode"]["decorrelation (yr)"],
                    "frequency (yr)": analysis["selected_mode"]["frequency (yr)"],
                    "residuals": analysis["selected_mode"]["residuals"],
                }
            ]
        )
    )



def plot_selected_heatmap(analysis: dict):
    mode_idx = analysis["selected_mode"]["mode_idx"]
    sign = analysis["selected_mode"]["sign"]
    plt.figure(figsize=(4, 3))
    plt.imshow((sign * analysis["gamma"][mode_idx]).real, cmap="RdBu_r")
    plt.colorbar()
    plt.title(f"{analysis['title']} | mode {mode_idx}")
    maybe_save_current_figure(f"{analysis['analysis_id']}_heatmap")
    plt.show()



def plot_selected_timeseries(analysis: dict):
    fig, ax = plt.subplots(figsize=(8, 3))
    ax.plot(analysis["times"], analysis["oni"], color="k", label="ONI")
    mode_series = analysis["mode_series"].copy()
    if np.ptp(mode_series) > 1e-12:
        mode_series = 6 * mode_series / np.ptp(mode_series)
    ax.plot(
        analysis["times"],
        mode_series - mode_series.mean(),
        color="tab:green",
        label="Selected mode",
    )
    ax.axhline(y=0, color="k", lw=0.5)
    ax.axvline(x=np.datetime64("2017-01-01"), color="grey", linestyle="--")
    ax.set_xmargin(0)
    ax.legend(loc="upper right")
    ax.set_title(f"corr(ONI, mode) = {analysis['selected_mode']['sign']*analysis['selected_mode']['oni_corr']:.3f}")
    maybe_save_current_figure(f"{analysis['analysis_id']}_timeseries")
    plt.show()



def plot_selected_overview(analysis: dict):
    lat = analysis["full_ds"].ds.latitude.values
    lon = analysis["full_ds"].ds.longitude.values
    lon = np.where(lon > 180, lon - 360, lon)
    lon2d, lat2d = np.meshgrid(lon, lat)
    spatial_mode = analysis["spatial_mode"]
    absmax = np.abs(spatial_mode).max()

    proj = ccrs.PlateCarree(central_longitude=180)
    fig, axs = plt.subplots(ncols=2, figsize=(10, 4), width_ratios=[1, 1])
    axs[0].remove()
    ax_map = plt.subplot(1, 2, 1, projection=proj)
    ax_map.pcolormesh(
        lon2d,
        lat2d,
        spatial_mode,
        cmap="RdBu_r",
        vmin=-absmax,
        vmax=absmax,
        transform=ccrs.PlateCarree(),
    )
    ax_map.add_feature(cfeature.LAND.with_scale("110m"), facecolor="lightgray", zorder=1)
    ax_map.coastlines(resolution="110m", linewidth=0.6)

    enso_regions = {
        "1+2": {"lon": 270, "lat": -10, "width": 10, "height": 10},
        "3": {"lon": 210, "lat": -5, "width": 60, "height": 10},
        "3.4": {"lon": 190, "lat": -5, "width": 50, "height": 10},
        "4": {"lon": 160, "lat": -5, "width": 50, "height": 10},
    }
    for name, props in enso_regions.items():
        color = "tab:red" if name == "3.4" else "black"
        box = Rectangle(
            (props["lon"], props["lat"]),
            props["width"],
            props["height"],
            edgecolor=color,
            facecolor="none",
            linewidth=0.5,
            transform=ccrs.PlateCarree(),
            alpha=0.8,
        )
        ax_map.add_patch(box)
        ax_map.text(
            props["lon"] + 2,
            props["lat"] + props["height"] + 1,
            name,
            transform=ccrs.PlateCarree(),
            fontsize=8,
            color=color,
        )

    ax_map.set_xticks([-120, -60, 0, 60, 120, 180], crs=ccrs.PlateCarree())
    ax_map.set_xticklabels(["120°W", "60°W", "0°", "60°E", "120°E", "180°"])
    ax_map.set_yticks([-90, -60, -30, 0, 30, 60, 90], crs=ccrs.PlateCarree())
    ax_map.set_yticklabels(["90°S", "60°S", "30°S", "0°", "30°N", "60°N", "90°N"])
    ax_map.set_global()

    ax_ts = axs[1]
    ax_ts.plot(analysis["times"], analysis["oni"], color="gray", alpha=1, label="ONI")
    eigfn = analysis["mode_series"] - np.mean(analysis["mode_series"])
    scale = np.max(np.abs(eigfn))
    if scale > 1e-12:
        eigfn = eigfn / scale * np.abs(analysis["oni"]).max()
    ax_ts.plot(analysis["times"], eigfn, color="tab:red", lw=1, label=r"$\Psi_{\mathrm{ENSO}}$")
    ax_ts.axhline(y=0, color="k", lw=0.5)
    ax_ts.axvline(x=np.datetime64("2017-01-01"), color="grey", linestyle="--")
    ax_ts.set_xlabel("Time", labelpad=2)
    ax_ts.set_ylabel(r"$\degree C$", labelpad=2)
    ax_ts.set_xmargin(0)
    ax_ts.legend(loc="upper right")

    fig.suptitle(analysis["title"])
    fig.tight_layout()
    maybe_save_current_figure(f"{analysis['analysis_id']}_overview")
    plt.show()



def show_selected_mode(analysis: dict):
    plot_selected_heatmap(analysis)
    plot_selected_timeseries(analysis)
    plot_selected_overview(analysis)



def summarize_analyses(analyses):
    rows = []
    for analysis in analyses:
        selected = analysis["selected_mode"]
        rows.append(
            {
                "setting": analysis["setting"],
                "method": analysis["method"],
                "mode_idx": selected["mode_idx"],
                "selection": selected["selection"],
                "oni_corr": selected["oni_corr"],
                "decorrelation (yr)": selected["decorrelation (yr)"],
                "frequency (yr)": selected["frequency (yr)"],
                "residuals": selected["residuals"],
                "checkpoint": analysis["checkpoint_file"],
            }
        )
    summary = pd.DataFrame(rows)
    return summary.sort_values(["setting", "method"]).reset_index(drop=True)



def run_enso_analysis(
    *,
    analysis_id: str,
    title: str,
    setting: str,
    method: str,
    checkpoint_file: str,
    checkpoint_data_source: str,
    feature_space: str,
    covariance_source: str,
    mode_idx_override=None,
):
    strict = feature_space == "evop"
    model, data_args, trainer_args, checkpoint_state = load_enso_checkpoint(
        checkpoint_file,
        strict=strict,
        expected_data_source=checkpoint_data_source,
    )

    maybe_prepare_sst_data(trainer_args, data_args, {checkpoint_data_source, analysis_source})
    train_ds, full_ds = build_sst_datasets(data_args, analysis_source)
    train_dl, full_dl = make_dataloaders(train_ds, full_ds)

    embeddings_train = collect_embeddings(model, train_dl, feature_space)
    embeddings_full = collect_embeddings(model, full_dl, feature_space)

    decomposition = solve_mode_decomposition(
        model,
        embeddings_train,
        embeddings_full,
        covariance_source=covariance_source,
    )

    oni_raw = full_ds.oni.SST.values[1 + data_args.history_len :]
    results = build_mode_table(
        decomposition["eigvals"],
        decomposition["Q"],
        embeddings_train,
        decomposition["right_efns"],
        oni_raw,
    )
    candidate_modes = build_candidate_modes(results)
    selected_mode = select_mode(results, candidate_modes, mode_idx_override=mode_idx_override)

    mode_idx = int(selected_mode["mode_idx"])
    signed_mode_series = (
        selected_mode["sign"]
        * decomposition["right_efns"][:, mode_idx].real.numpy(force=True)
    )
    times, oni, mode_series = align_time_series(
        embeddings_full["times"],
        oni_raw,
        signed_mode_series,
        min_length=2,
    )

    if len(times) != len(oni) or len(oni) != len(mode_series):
        raise AssertionError("Time, ONI, and mode series must have the same length.")

    spatial_mode = selected_mode["sign"] * decomposition["modes"][mode_idx].real
    obs_mode_ds = build_obs_mode_dataset(times, mode_series, spatial_mode, train_ds)

    return {
        "analysis_id": analysis_id,
        "title": title,
        "setting": setting,
        "method": method,
        "checkpoint_file": checkpoint_file,
        "checkpoint_state": checkpoint_state,
        "data_args": data_args,
        "trainer_args": trainer_args,
        "model": model,
        "train_ds": train_ds,
        "full_ds": full_ds,
        "embeddings_train": embeddings_train,
        "embeddings_full": embeddings_full,
        "results": results,
        "candidate_modes": candidate_modes,
        "selected_mode": selected_mode,
        "times": times,
        "oni": oni,
        "mode_series": mode_series,
        "spatial_mode": spatial_mode,
        "obs_mode_ds": obs_mode_ds,
        **decomposition,
    }

# %% [markdown]
# ## Transfer Learning
#
# All three checkpoints below were trained on `CESM` and are analyzed on `ORAS5`.

# %% [markdown]
# ### Ours - Evolution Operator

# %%
evop_transfer = run_enso_analysis(
    analysis_id="evop_transfer",
    title="Evolution Operator transfer (CESM → ORAS5)",
    setting="transfer",
    method="Evolution Operator",
    checkpoint_file="ENSO/EvOp_CESM.pt",
    checkpoint_data_source="CESM",
    feature_space="evop",
    covariance_source="empirical",
    mode_idx_override=mode_overrides["evop_transfer"],
)
display_candidate_modes(evop_transfer)

# %%
show_selected_mode(evop_transfer)

# %% [markdown]
# ### VAMPNets

# %%
vamp_transfer = run_enso_analysis(
    analysis_id="vamp_transfer",
    title="VAMPNets transfer (CESM → ORAS5)",
    setting="transfer",
    method="VAMPNets",
    checkpoint_file="ENSO/VAMPNets_CESM.pt",
    checkpoint_data_source="CESM",
    feature_space="baseline",
    covariance_source="empirical",
    mode_idx_override=mode_overrides["vamp_transfer"],
)
display_candidate_modes(vamp_transfer)

# %%
show_selected_mode(vamp_transfer)

# %% [markdown]
# ### DPNets

# %%
dp_transfer = run_enso_analysis(
    analysis_id="dp_transfer",
    title="DPNets transfer (CESM → ORAS5)",
    setting="transfer",
    method="DPNets",
    checkpoint_file="ENSO/DPNets_CESM.pt",
    checkpoint_data_source="CESM",
    feature_space="baseline",
    covariance_source="empirical",
    mode_idx_override=mode_overrides["dp_transfer"],
)
display_candidate_modes(dp_transfer)

# %%
show_selected_mode(dp_transfer)

# %% [markdown]
# ## No Transfer Learning
#
# All three checkpoints below were trained and analyzed on `ORAS5`.

# %% [markdown]
# ### Ours - Evolution Operator

# %%
evop_notransfer = run_enso_analysis(
    analysis_id="evop_notransfer",
    title="Evolution Operator no transfer (ORAS5)",
    setting="no_transfer",
    method="Evolution Operator",
    checkpoint_file="ENSO/EvOp_ORAS5.pt",
    checkpoint_data_source="ORAS5",
    feature_space="evop",
    covariance_source="checkpoint",
    mode_idx_override=mode_overrides["evop_notransfer"],
)
display_candidate_modes(evop_notransfer)

# %%
show_selected_mode(evop_notransfer)

# %% [markdown]
# ### VAMPNets

# %%
vamp_notransfer = run_enso_analysis(
    analysis_id="vamp_notransfer",
    title="VAMPNets no transfer (ORAS5)",
    setting="no_transfer",
    method="VAMPNets",
    checkpoint_file="ENSO/VAMPNets_ORAS5.pt",
    checkpoint_data_source="ORAS5",
    feature_space="baseline",
    covariance_source="empirical",
    mode_idx_override=mode_overrides["vamp_notransfer"],
)
display_candidate_modes(vamp_notransfer)

# %%
show_selected_mode(vamp_notransfer)

# %% [markdown]
# ### DPNets

# %%
dp_notransfer = run_enso_analysis(
    analysis_id="dp_notransfer",
    title="DPNets no transfer (ORAS5)",
    setting="no_transfer",
    method="DPNets",
    checkpoint_file="ENSO/DPNets_ORAS5.pt",
    checkpoint_data_source="ORAS5",
    feature_space="baseline",
    covariance_source="empirical",
    mode_idx_override=mode_overrides["dp_notransfer"],
)
display_candidate_modes(dp_notransfer)

# %%
show_selected_mode(dp_notransfer)

# %% [markdown]
# ## Comparison Summary
#
# This final table collects the automatically selected (or manually overridden) ENSO mode for every method.

# %%
comparison = summarize_analyses(
    [
        evop_transfer,
        vamp_transfer,
        dp_transfer,
        evop_notransfer,
        vamp_notransfer,
        dp_notransfer,
    ]
)
comparison
